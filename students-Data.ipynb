# %% [markdown]
# # Students Data

# %%
students = {
"ALI": 30, 
"Ahmed": 50,
"Zohaib": 45,
"Asad": 42,
"Abdullah": 46, 
"Awais": 70
}

# %%
for i in range(len(students)):
    for name, score in students[i].items():
        print(f"Name: {name}, Score: {score}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 for i in range(len(students)):
# ----> 2     for name, score in students[i].items():
#       3         print(f"Name: {name}, Score: {score}")
#       4
#
# KeyError: 0
