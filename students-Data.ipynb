# %% [markdown]
# # Students Data

# %%
students = {
"ALI": 30, 
"Ahmed": 50,
"Zohaib": 45,
"Asad": 42,
"Abdullah": 46, 
"Awais": 70
}

# %%
for name, score in students.items():
    print(f"Name: {name}, Score: {score}")
# Out:
# Name: ALI, Score: 30
# Name: Ahmed, Score: 50
# Name: Zohaib, Score: 45
# Name: Asad, Score: 42
# Name: Abdullah, Score: 46
# Name: Awais, Score: 70
